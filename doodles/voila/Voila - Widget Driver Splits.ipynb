# %%
# %%capture
import notebookimport

ds= __import__("Report - Driver Splits")

# %%
import sqlite3
from IPython.display import HTML
import pandas as pd

#Set near zero display to zero
#Doesn't have any effect?
pd.set_option('display.chop_threshold', 0.001)

dbname='testdata/finland19a.db'
conn = sqlite3.connect(dbname)
rally='Finland'
rc='RC1'
YEAR = year=2019

# %%
q_drivers='SELECT `driver.code` AS code  FROM startlists st JOIN startlist_classes sc ON sc.entryid = st.entryid AND name="{}"'

q_classes='SELECT DISTINCT(name) AS name FROM startlists st JOIN startlist_classes sc ON sc.entryid = st.entryid'

q_stages= 'SELECT * FROM itinerary_stages WHERE status!="ToRun" ORDER BY Number'

# %%
import dakar_utils as dakar
import ipywidgets as widgets
from ipywidgets import interact

# %% [markdown]
# ## How About More Control?
#
# What about we let the user decide what to allow in each chart?

# %% [markdown]
# THink about adding some pace notes to the table. For example, a column showing what the pace was on the current stage in terms of s / km gained or lost, the pace required in the next stage to compensate for the gap to other drivers from the rebased driver, the pace required over the rest of the stages in the loop, or over the next loop.

# %%
classes2 = widgets.Dropdown(
    options=pd.read_sql(q_classes,conn)['name'].to_list(),
    value='RC1',
    description='Class:',
    disabled=False,
)

drivers2 = widgets.Dropdown(
    options=pd.read_sql(q_drivers.format(classes2.value),conn)['code'].to_list(),
    #value='NEU',
    description='Driver:',
    disabled=False,
)

stages2 = widgets.Dropdown(
    options=pd.read_sql(q_stages,conn)['code'].to_list(), description='Stage:', disabled=False)


def stage_chart2(rc,driver, stage, bars, roadPos, waypointRank, previous):
    dropcols=[]
    if not roadPos:
        dropcols.append('Road Position')
    if not waypointRank:
        dropcols.append('Waypoint Rank')
    if not previous:
        dropcols.append('Previous')
        
    s2 = ds.getDriverSplitsReport(conn, rally, stage, driver, rc,
                                  bars=bars, dropcols=dropcols)
    display(HTML(s2))

splitBars = widgets.Checkbox( value=True, description='Split bars:',
                           disabled=False )
    
roadPos = widgets.Checkbox( value=True, description='Road pos',
                           disabled=False )

waypointRank = widgets.Checkbox( value=True, description='Waypoint Rank',
                           disabled=False )

previous = widgets.Checkbox( value=True, description='Previous',
                           disabled=False )


def update_drivers2(*args):
    qdrivers = q_drivers.format(classes2.value)
    driverlist = pd.read_sql(qdrivers,conn)['code'].to_list()
    print(driverlist)
    drivers2.options = driverlist
    
classes2.observe(update_drivers2, 'value')


#Add sort order

interact(stage_chart2, rc=classes2, driver=drivers2,
         stage=stages2, bars=splitBars, roadPos=roadPos,
        waypointRank=waypointRank, previous=previous);
# Out:
# interactive(children=(Dropdown(description='Class:', options=('RC1', 'RC2', 'RC4', 'RC3', 'RC5'), value='RC1')…

# %%
import testRequiredPace as pace

# %%
pace.conn = conn
pace.rally = rally
pace.YEAR = year

pace.distances = pace.stageDistances(conn)

# %%
from dakar_utils import moreStyleDriverSplitReportBaseDataframe

driver='LAT'
tmp =  pace.multiStagePaceReport(['SS{}'.format(i) for i in range(1,24)], driver )

#The negative map means we get times as the rebased driver is concerned...
s2 = moreStyleDriverSplitReportBaseDataframe(-tmp.loc[,:],'')
display(HTML(s2))
# Out:
# Stage dist is 2.31 km
# Stage dist is 19.34 km
# Stage dist is 20.04 km
# Stage dist is 12.28 km
# Stage dist is 12.33 km
# Stage dist is 7.8 km
# Stage dist is 20.04 km
# Stage dist is 12.28 km
# Stage dist is 12.33 km
# Stage dist is 7.8 km
# Stage dist is 2.31 km
# Stage dist is 14.42 km
# Stage dist is 22.87 km
# Stage dist is 18.7 km
# Stage dist is 10.5 km
# Stage dist is 14.42 km
# Stage dist is 22.87 km
# Stage dist is 18.7 km
# Stage dist is 10.5 km
# Stage dist is 11.75 km
# Stage dist is 11.12 km
# Stage dist is 11.75 km
# Stage dist is 11.12 km
# <style  type="text/css" >
#     #T_60de6422_b701_11e9_938e_645aede917f3 th {
#           font-size: 11px;
#           text-align: center;
#           font-weight: bold;
#           color: #6d6d6d;
#           background-color: #f7f7f9;
#     }    #T_60de6422_b701_11e9_938e_645aede917f3 td {
#           font-size: 11px;
#     }    #T_60de6422_b701_11e9_938e_645aede917f3row0_col0 {
#             color:  red;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, #d65f5f 50.0%, #d65f5f 78.3%, transparent 78.3%);
#         }    #T_60de6422_b701_11e9_938e_645aede917f3row0_col1 {
#             color:  green;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 46.8%, #5fba7d 46.8%, #5fba7d 50.0%, transparent 50.0%);
#         }    #T_60de6422_b701_11e9_938e_645aede917f3row0_col2 {
#             color:  red;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, #d65f5f 50.0%, #d65f5f 66.1%, transparent 66.1%);
#         }    #T_60de6422_b701_11e9_938e_645aede917f3row0_col3 {
#             color:  green;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 42.0%, #5fba7d 42.0%, #5fba7d 50.0%, transparent 50.0%);
#         }    #T_60de6422_b701_11e9_938e_645aede917f3row0_col4 {
#             color:  red;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, #d65f5f 50.0%, #d65f5f 59.4%, transparent 59.4%);
#         }    #T_60de6422_b701_11e9_938e_645aede917f3row0_col5 {
#             color:  green;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 45.8%, #5fba7d 45.8%, #5fba7d 50.0%, transparent 50.0%);
#         }    #T_60de6422_b701_11e9_938e_645aede917f3row0_col6 {
#             color:  green;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 29.7%, #5fba7d 29.7%, #5fba7d 50.0%, transparent 50.0%);
#         }    #T_60de6422_b701_11e9_938e_645aede917f3row0_col7 {
#             color:  green;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 48.8%, #5fba7d 48.8%, #5fba7d 50.0%, transparent 50.0%);
#         }    #T_60de6422_b701_11e9_938e_645aede917f3row0_col8 {
#             color:  green;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 43.2%, #5fba7d 43.2%, #5fba7d 50.0%, transparent 50.0%);
#         }    #T_60de6422_b701_11e9_938e_645aede917f3row0_col9 {
#             color:  green;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 38.6%, #5fba7d 38.6%, #5fba7d 50.0%, transparent 50.0%);
#         }    #T_60de6422_b701_11e9_938e_645aede917f3row0_col10 {
#             color:  red;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, #d65f5f 50.0%, #d65f5f 58.9%, transparent 58.9%);
#         }    #T_60de6422_b701_11e9_938e_645aede917f3row0_col11 {
#             color:  red;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, #d65f5f 50.0%, #d65f5f 57.0%, transparent 57.0%);
#         }    #T_60de6422_b701_11e9_938e_645aede917f3row0_col12 {
#             color:  green;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 48.3%, #5fba7d 48.3%, #5fba7d 50.0%, transparent 50.0%);
#         }    #T_60de6422_b701_11e9_938e_645aede917f3row0_col13 {
#             color:  red;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, #d65f5f 50.0%, #d65f5f 96.1%, transparent 96.1%);
#         }    #T_60de6422_b701_11e9_938e_645aede917f3row0_col14 {
#             color:  green;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 49.7%, #5fba7d 49.7%, #5fba7d 50.0%, transparent 50.0%);
#         }    #T_60de6422_b701_11e9_938e_645aede917f3row0_col15 {
#             color:  red;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, #d65f5f 50.0%, #d65f5f 61.3%, transparent 61.3%);
#         }    #T_60de6422_b701_11e9_938e_645aede917f3row0_col16 {
#             color:  red;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, #d65f5f 50.0%, #d65f5f 71.4%, transparent 71.4%);
#         }    #T_60de6422_b701_11e9_938e_645aede917f3row0_col17 {
#             color:  red;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, #d65f5f 50.0%, #d65f5f 67.2%, transparent 67.2%);
#         }    #T_60de6422_b701_11e9_938e_645aede917f3row0_col18 {
#             color:  red;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, #d65f5f 50.0%, #d65f5f 57.4%, transparent 57.4%);
#         }    #T_60de6422_b701_11e9_938e_645aede917f3row0_col19 {
#             color:  red;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, #d65f5f 50.0%, #d65f5f 58.3%, transparent 58.3%);
#         }    #T_60de6422_b701_11e9_938e_645aede917f3row0_col20 {
#             color:  green;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 39.7%, #5fba7d 39.7%, #5fba7d 50.0%, transparent 50.0%);
#         }    #T_60de6422_b701_11e9_938e_645aede917f3row0_col21 {
#             color:  red;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, #d65f5f 50.0%, #d65f5f 53.4%, transparent 53.4%);
#         }    #T_60de6422_b701_11e9_938e_645aede917f3row0_col22 {
#             color:  red;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, #d65f5f 50.0%, #d65f5f 100.0%, transparent 100.0%);
#         }    #T_60de6422_b701_11e9_938e_645aede917f3row1_col0 {
#             color:  green;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 38.3%, #5fba7d 38.3%, #5fba7d 50.0%, transparent 50.0%);
#         }    #T_60de6422_b701_11e9_938e_645aede917f3row1_col1 {
#             color:  green;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 49.6%, #5fba7d 49.6%, #5fba7d 50.0%, transparent 50.0%);
#         }    #T_60de6422_b701_11e9_938e_645aede917f3row1_col2 {
#             color:  green;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 48.9%, #5fba7d 48.9%, #5fba7d 50.0%, transparent 50.0%);
#         }    #T_60de6422_b701_11e9_938e_645aede917f3row1_col3 {
#             color:  green;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 42.0%, #5fba7d 42.0%, #5fba7d 50.0%, transparent 50.0%);
#         }    #T_60de6422_b701_11e9_938e_645aede917f3row1_col4 {
#             color:  red;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, #d65f5f 50.0%, #d65f5f 55.2%, transparent 55.2%);
#         }    #T_60de6422_b701_11e9_938e_645aede917f3row1_col5 {
#             color:  green;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 39.8%, #5fba7d 39.8%, #5fba7d 50.0%, transparent 50.0%);
#         }    #T_60de6422_b701_11e9_938e_645aede917f3row1_col6 {
#             color:  green;
#             width:  10em;
#              height:  80%;

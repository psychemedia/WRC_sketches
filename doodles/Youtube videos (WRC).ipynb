# %% [markdown]
# ## Youtube videos (WRC)

# %%
#https://github.com/rohitkhatri/youtube-python
import requests


class YouTube:
    api_key = None
    access_token = None
    api_base_url = 'https://www.googleapis.com/youtube/v3/'
    part = 'contentDetails'

    def __init__(self, api_key, access_token=None, api_url=None):
        self.api_key = api_key
        self.access_token = access_token

        if api_url:
            self.api_url = api_url

    def get(self, endpoint, **kwargs):
        if self.access_token:
            kwargs['access_token'] = self.access_token
        else:
            kwargs['key'] = self.api_key

        if 'part' not in kwargs:
            kwargs['part'] = self.part
        url=self.api_base_url+endpoint
        return self.response(requests.get(url, params=kwargs))

    @staticmethod
    def response(response):
        return response.json()

# %%
api = YouTube(api_key='AIzaSyBX8edTm2JU6uYFI7RqcXdnlQVKnQuBD8o')

# %%
api.get('channels', id='UCLFZ5qAH-l_WiRd_EOzX2og')
# Out:
# {'kind': 'youtube#channelListResponse',
#  'etag': '"ZG3FIn5B5vcHjQiQ9nDOCWdxwWo/BmKNnZY8un1F1zlSgNEHQfogm8A"',
#  'pageInfo': {'totalResults': 1, 'resultsPerPage': 1},
#  'items': [{'kind': 'youtube#channel',
#    'etag': '"ZG3FIn5B5vcHjQiQ9nDOCWdxwWo/n0ZrdKFMzUHpO64Xd9U60rrfRLk"',
#    'id': 'UCLFZ5qAH-l_WiRd_EOzX2og',
#    'contentDetails': {'relatedPlaylists': {'uploads': 'UULFZ5qAH-l_WiRd_EOzX2og',
#      'watchHistory': 'HL',
#      'watchLater': 'WL'}}}]}

# %%
api.get('channels', forUsername='WRC')
# Out:
# {'kind': 'youtube#channelListResponse',
#  'etag': '"ZG3FIn5B5vcHjQiQ9nDOCWdxwWo/EXkWOZsBIA3R2_BOHBDIFbAzTYs"',
#  'pageInfo': {'totalResults': 1, 'resultsPerPage': 5},
#  'items': [{'kind': 'youtube#channel',
#    'etag': '"ZG3FIn5B5vcHjQiQ9nDOCWdxwWo/JBGvFL9MVZeF-k40G2vCEZEBB_4"',
#    'id': 'UC5G6kTnHXDz0WIBC2VGBOqg',
#    'contentDetails': {'relatedPlaylists': {'uploads': 'UU5G6kTnHXDz0WIBC2VGBOqg',
#      'watchHistory': 'HL',
#      'watchLater': 'WL'}}}]}

# %%
api.get('playlistItems',part='snippet', playlistId='UU5G6kTnHXDz0WIBC2VGBOqg')
# Out:
# {'kind': 'youtube#playlistItemListResponse',
#  'etag': '"ZG3FIn5B5vcHjQiQ9nDOCWdxwWo/B-6l3yshEu22r97GaRIdIchMbbE"',
#  'nextPageToken': 'CAUQAA',
#  'pageInfo': {'totalResults': 2623, 'resultsPerPage': 5},
#  'items': [{'kind': 'youtube#playlistItem',
#    'etag': '"ZG3FIn5B5vcHjQiQ9nDOCWdxwWo/3iGTzHhcRgaThcVhwpocNhlvaj8"',
#    'id': 'VVU1RzZrVG5IWER6MFdJQkMyVkdCT3FnLjlCTkdQTDZwbkw4',
#    'snippet': {'publishedAt': '2018-04-29T15:44:26.000Z',
#     'channelId': 'UC5G6kTnHXDz0WIBC2VGBOqg',
#     'title': 'WRC - YPF Rally Argentina 2018: Highlights SS16',
# ...

# %%
api.get('search',part='snippet', q='WRC - YPF Rally Argentina 2018',channel='UU5G6kTnHXDz0WIBC2VGBOqg')
# Out:
# {'kind': 'youtube#searchListResponse',
#  'etag': '"ZG3FIn5B5vcHjQiQ9nDOCWdxwWo/bSRyhpEr9heKtHLOUTBbEpdUDDs"',
#  'nextPageToken': 'CAUQAA',
#  'regionCode': 'GB',
#  'pageInfo': {'totalResults': 8060, 'resultsPerPage': 5},
#  'items': [{'kind': 'youtube#searchResult',
#    'etag': '"ZG3FIn5B5vcHjQiQ9nDOCWdxwWo/OdiWNtk1K-H4G3ZOIFbSFw1mAjw"',
#    'id': {'kind': 'youtube#video', 'videoId': '9BNGPL6pnL8'},
#    'snippet': {'publishedAt': '2018-04-29T15:44:26.000Z',
#     'channelId': 'UC5G6kTnHXDz0WIBC2VGBOqg',
#     'title': 'WRC - YPF Rally Argentina 2018: Highlights SS16',
#     'description': 'FIA World Rally Championship - YPF Rally Argentina 2018 SS16 COPINA - EL CONDOR (16.43 km) ▻ Watch ALL HIGHLIGHTS on http://www.wrcplus.com ▻ More WRC Videos: http://goo.gl/kKumd8 ▻...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/9BNGPL6pnL8/default.jpg',
#       'width': 120,
#       'height': 90},
# ...
